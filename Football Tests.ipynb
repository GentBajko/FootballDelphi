# %%
from datetime import date, timedelta, datetime
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import os
from scipy.stats import poisson
import numpy as np
from selenium.webdriver.chrome.options import Options

matches = pd.read_excel('C:\\Users\\GentB\\OneDrive\\Documents\\Python\\2020\\FootballPredictions.py/dropna.xlsx',
                        sheet_name='Database')

# %%
def under05(homeS, awayS):
    result = ((poisson.pmf(0, homeS) * poisson.pmf(0, awayS)))
    return round(float(np.array2string(result)), 5)

# %%
under05(1, 1)
# Out:
# -8546.599999999999

# %%
1 - under05(1, 1)
# Out:
# 0.86466

# %%
matches.values
# Out:
# array([[54, '2019-08-01', 'Panama', ..., 0.40601, 0.0, 0.01],
#        [146, '2019-08-02', 'Forge Fc', ..., 0.19915, 0.02, 0.01],
#        [161, '2019-08-02', 'Jamaica', ..., 0.40601, 0.0, 0.02],
#        ...,
#        [31112, '2020-03-08', 'Venezuela', ..., 0.19915, 0.02, 0.01],
#        [31113, '2020-03-08', 'Chile', ..., 0.1847, 0.02, 0.03],
#        [31114, '2020-03-08', 'Brazil', ..., 0.08459, 0.03, 0.0]],
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
import scipy
import numpy

# %%
X = array[:,0:8]
Y = array[:,8]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
rescaledX = scaler.fit_transform(X)
re

# %%
numpy.set_printoptions(precision=3)
print(rescaledX[0:5,:])
# Out:
# [[0.000e+00       nan       nan       nan       nan       nan       nan
#         nan]
#  [3.214e-05       nan       nan       nan       nan       nan       nan
#         nan]
#  [6.428e-05       nan       nan       nan       nan       nan       nan
#         nan]
#  [9.642e-05       nan       nan       nan       nan       nan       nan
#         nan]
#  [1.286e-04       nan       nan       nan       nan       nan       nan
#         nan]]

# %%
from matplotlib import pyplot

# %%
pyplot.plot(rescaledX, Y)

# %%
numpyarr = df.reset_index().values

# %%
import sys
numpy.set_printoptions(threshold=sys.maxsize)

# %%
numpyarr
# Out:
# array([[0.000e+00, 5.400e+01, 1.000e-02, 1.000e-02, 1.353e-01, 4.060e-01,
#         6.767e-01, 5.940e-01, 4.060e-01, 0.000e+00, 1.000e-02],
#        [1.000e+00, 1.460e+02, 2.000e-02, 1.000e-02, 4.979e-02, 1.991e-01,
#         4.232e-01, 8.008e-01, 1.991e-01, 2.000e-02, 1.000e-02],
#        [2.000e+00, 1.610e+02, 0.000e+00, 2.000e-02, 1.353e-01, 4.060e-01,
#         6.767e-01, 5.940e-01, 4.060e-01, 0.000e+00, 2.000e-02],
#        [3.000e+00, 2.050e+02, 0.000e+00, 3.000e-02, 4.979e-02, 1.991e-01,
#         4.232e-01, 8.008e-01, 1.991e-01, 0.000e+00, 3.000e-02],
#        [4.000e+00, 3.590e+02, 1.000e-02, 0.000e+00, 3.679e-01, 7.358e-01,
#         9.197e-01, 2.642e-01, 7.358e-01, 1.000e-02, 0.000e+00],
#        [5.000e+00, 3.750e+02, 1.000e-02, 1.000e-02, 1.353e-01, 4.060e-01,
#         6.767e-01, 5.940e-01, 4.060e-01, 0.000e+00, 3.000e-02],
#        [6.000e+00, 3.780e+02, 0.000e+00, 1.000e-02, 3.679e-01, 7.358e-01,
#         9.197e-01, 2.642e-01, 7.358e-01, 4.000e-02, 1.000e-02],
# ...

# %%
df = matches.drop(['Home Team', 'Away Team', 'Date'], axis=1)

# %%
dataset = df.index.drop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-92e997707059> in <module>
# ----> 1 dataset = df.index.drop()
#
# TypeError: drop() missing 1 required positional argument: 'labels'

# %%
print(dataset)
# Out:
# <bound method Index.drop of RangeIndex(start=0, stop=25392, step=1)>
